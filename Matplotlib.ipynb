# %% [markdown]
# <a href="https://colab.research.google.com/github/KOLLAVARSH/PYTHON-PROJECT/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint = np.array([2,3,5,6])
ypoint = np.array([3,6,8,4])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([10, 4, 2, 9])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.barh(x, y,color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.barh(x, y,color = "yellow")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.bar(x, y,width = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.barh(x, y,height = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([90,5,3,2])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
color1 = (["orange","red","yellow","blue","pink","green","white","black","violet","gold","silver"])
x = np.array(['CLAD1001','CSEN1001','CSEN1011',	'LANG1001','MATH1001','MATH1011','MECH1021','PHYS1001','VEDC1001'])
y = np.array([86,85,80,91,92,95,98,92,59])
plt.bar(x,y,color = color1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([25,50,5,20])
subjects = (["maths","physics","chemistry","python"])
plt.pie(y,labels = subjects)
plt.show()
